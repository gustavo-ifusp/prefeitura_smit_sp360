# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo-ifusp/prefeitura_smit_sp360/blob/main/saude_profissionais_salarios_por_carreira.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# #**Saúde -> Dados dos profissionais da saúde (Qtde e salários por carreira)**

# %%
with open('smit.csv') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='smit.csv' mode='r' encoding='UTF-8'>

# %%
dados = pd.read_csv("smit.csv", sep = ';', encoding="ISO-8859-1")

# %%
dados
# Out:
#               QUALIFICADOR       VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 0                    TODOS          TODOS       93387     SISRH  16/11/2021
# 1   VINCULO DE CONTRATACAO           HSPM        1607     SISRH  16/11/2021
# 2   VINCULO DE CONTRATACAO       PARCEIRA       67106     SISRH  16/11/2021
# 3   VINCULO DE CONTRATACAO       ESTADUAL        1742     SISRH  16/11/2021
# 4   VINCULO DE CONTRATACAO      MUNICIPAL       22737     SISRH  16/11/2021
# ..                     ...            ...         ...       ...         ...
# 89      ORGANIZACAO SOCIAL  PADRE MOREIRA         342     SISRH  16/11/2021
# 90      ORGANIZACAO SOCIAL           SPDM       17488     SISRH  16/11/2021
# 91                ENTRADAS       ENTRADAS          26     SISRH  16/11/2021
# 92                  SAIDAS         SAIDAS          33     SISRH  16/11/2021
# 93    ATENDIMENTOS EX-PROF           2021       21492      SAPS  17/11/2021
#
# [94 rows x 5 columns]

# %%
dados['QUALIFICADOR'].unique()
# Out:
# array(['TODOS', 'VINCULO DE CONTRATACAO', 'COORDENADORIA',
#        'REGIME JURIDICO', 'AREA DE ATIVIDADE', 'SEXO BIOLOGICO',
#        'NIVEL CATEGORIA', 'ORGANIZACAO SOCIAL', 'APOSENTADORIAS',
#        'ENTRADAS', 'SAIDAS', 'ATENDIMENTOS EX-PROF'], dtype=object)

# %%
dados['VARIAVEL'].unique()
# Out:
# array(['TODOS', 'HSPM', 'PARCEIRA', 'ESTADUAL', 'MUNICIPAL',
#        'MAIS MEDICOS', 'FEDERAL',
#        'HM HOSPITAL INTEGRADO SANTO AMARO AMBULATORIO DE ESPECIALIDADE',
#        'HOSPITAL DO SERVIDOR PUBLICO MUNICIPAL HSPM',
#        'COORDENADORIA REGIONAL DE SAUDE NORTE', 'HM BRASILANDIA',
#        'COORDENADORIA REGIONAL DE SAUDE SUDESTE',
#        'ESCOLA MUNICIPAL DE SAUDE',
#        'HM CIDADE TIRADENTES CARMEN PRUDENTE',
#        'HM E MATERNIDADE PROF MARIO DEGNI JD SARAH', 'HM SOROCABANA',
#        'COORDENADORIA REGIONAL DE SAUDE LESTE',
#        'HM M BOI MIRIM DR MOYSES DEUTSCH',
#        'HM DR IGNACIO PROENCA DE GOUVEA',
#        'HM DR JOSE SOARES HUNGRIA PIRITUBA', 'SAMU SEDE',
#        'HM VILA SANTA CATARINA GILSON DE CASSIA MARQUES DE CARVALHO',
#        'COORDENADORIA REGIONAL DE SAUDE SUL',
#        'HM DR ALEXANDRE ZAIO VILA NHOCUNE',
#        'COORDENADORIA DE VIGILANCIA EM SAUDE COVISA',
#        'HM PROF DR ALIPIO CORREA NETTO ERMELINO MATARAZZO',
#        'HM DR CARMINO CARICCHIO TATUAPE',
#        'HM E MATERN ESCOLA DR  MARIO DE M A DA SILVA  CACHOEIRINHA',
#        'COORDENADORIA REGIONAL DE SAUDE OESTE', 'GABINETE SMSG SEDE',
#        'HM INFANTIL MENINO JESUS',
#        'COORDENADORIA REGIONAL DE SAUDE CENTRO',
#        'HM PROF DR WALDOMIRO DE PAULA ITAQUERA PLANALTO',
#        'HM JOSANIAS CASTANHA BRAGA PARELHEIROS', 'HM GUARAPIRANGA',
#        'HM DR FERNANDO MAURO PIRES DA ROCHA CAMPO LIMPO',
#        'HM DR ARTHUR RIBEIRO SABOYA JABAQUARA', 'HM SAO LUIZ GONZAGA',
#        'HM VEREADOR JOSE STOROPOLLI V MARIA',
#        'HM DR BENEDICTO MONTENEGRO JARDIM IVA', 'EM TRANSITO',
#        'HM TIDE SETUBAL SAO MIGUEL', 'PESSOA JURIDICA', 'EFETIVO',
#        'MAIS MEDICOS INTERCAMBISTA', 'CLT', 'ADMITIDO ESTAVEL',
#        'ADMITIDO NAO ESTAVEL', 'MAIS MEDICOS BOLSISTA',
#        'MAIS MEDICOS COOPERADO', 'K CARGO EM COMISSÃO',
#        'ADMITIDO LEI 500', 'CONTRATO DE EMERGENCIA',
#        'URGENCIA E EMERGENCIA', 'ATENCAO BASICA', 'ATENCAO ESPECIALIZADA',
#        'ATENCAO HOSPITALAR', 'GESTAO', 'VIGILANCIA EM SAUDE', 'M', 'F',
#        'O', 'S', 'BOM PARTO', 'IABAS', 'SIRIO LIBANES', 'PROSAM', 'SPX',
#        '2021', 'ALBERT EINSTEIN', 'FUNDACAO ABC', 'CEJAM', 'SEPACO',
#        'FFM', 'CASA DE ISABEL', 'INTS', 'SANTA CASA DE SAO PAULO',
#        'QUIXOTE', 'ASF', 'APAE', 'SANTA CATARINA', 'FIDI',
#        'SANTA MARCELINA', 'IRMAS HOSPITALEIRAS', 'SALUS CREN',
#        'MONTE AZUL', 'SECONCI', 'PADRE MOREIRA', 'SPDM', 'ENTRADAS',
#        'SAIDAS'], dtype=object)

# %%
dados['SISORIGEM'].unique()
# Out:
# array(['SISRH', 'CRH3', 'SAPS'], dtype=object)

# %%
dados['FREQUENCIA'].sum()
# Out:
# 743504

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'TODOS']
# Out:
#   QUALIFICADOR VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 0        TODOS    TODOS       93387     SISRH  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'VINCULO DE CONTRATACAO']
# Out:
#              QUALIFICADOR      VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 1  VINCULO DE CONTRATACAO          HSPM        1607     SISRH  16/11/2021
# 2  VINCULO DE CONTRATACAO      PARCEIRA       67106     SISRH  16/11/2021
# 3  VINCULO DE CONTRATACAO      ESTADUAL        1742     SISRH  16/11/2021
# 4  VINCULO DE CONTRATACAO     MUNICIPAL       22737     SISRH  16/11/2021
# 5  VINCULO DE CONTRATACAO  MAIS MEDICOS         165     SISRH  16/11/2021
# 6  VINCULO DE CONTRATACAO       FEDERAL          30     SISRH  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'COORDENADORIA']
# Out:
#      QUALIFICADOR  ... ATUALIZACAO
# 7   COORDENADORIA  ...  16/11/2021
# 8   COORDENADORIA  ...  16/11/2021
# 9   COORDENADORIA  ...  16/11/2021
# 10  COORDENADORIA  ...  16/11/2021
# 11  COORDENADORIA  ...  16/11/2021
# 12  COORDENADORIA  ...  16/11/2021
# 13  COORDENADORIA  ...  16/11/2021
# 14  COORDENADORIA  ...  16/11/2021
# 15  COORDENADORIA  ...  16/11/2021
# 16  COORDENADORIA  ...  16/11/2021
# 17  COORDENADORIA  ...  16/11/2021
# 18  COORDENADORIA  ...  16/11/2021
# 19  COORDENADORIA  ...  16/11/2021
# 20  COORDENADORIA  ...  16/11/2021
# 21  COORDENADORIA  ...  16/11/2021
# 22  COORDENADORIA  ...  16/11/2021
# 23  COORDENADORIA  ...  16/11/2021
# 24  COORDENADORIA  ...  16/11/2021
# 25  COORDENADORIA  ...  16/11/2021
# 26  COORDENADORIA  ...  16/11/2021
# 27  COORDENADORIA  ...  16/11/2021
# 28  COORDENADORIA  ...  16/11/2021
# 29  COORDENADORIA  ...  16/11/2021
# 30  COORDENADORIA  ...  16/11/2021
# 31  COORDENADORIA  ...  16/11/2021
# 32  COORDENADORIA  ...  16/11/2021
# 33  COORDENADORIA  ...  16/11/2021
# 34  COORDENADORIA  ...  16/11/2021
# 35  COORDENADORIA  ...  16/11/2021
# 36  COORDENADORIA  ...  16/11/2021
# 37  COORDENADORIA  ...  16/11/2021
# 38  COORDENADORIA  ...  16/11/2021
# 39  COORDENADORIA  ...  16/11/2021
# 40  COORDENADORIA  ...  16/11/2021
# 41  COORDENADORIA  ...  16/11/2021
#
# [35 rows x 5 columns]

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'REGIME JURIDICO']
# Out:
#        QUALIFICADOR                    VARIAVEL  ...  SISORIGEM ATUALIZACAO
# 42  REGIME JURIDICO             PESSOA JURIDICA  ...      SISRH  16/11/2021
# 43  REGIME JURIDICO                     EFETIVO  ...      SISRH  16/11/2021
# 44  REGIME JURIDICO  MAIS MEDICOS INTERCAMBISTA  ...      SISRH  16/11/2021
# 45  REGIME JURIDICO                         CLT  ...      SISRH  16/11/2021
# 46  REGIME JURIDICO            ADMITIDO ESTAVEL  ...      SISRH  16/11/2021
# 47  REGIME JURIDICO        ADMITIDO NAO ESTAVEL  ...      SISRH  16/11/2021
# 48  REGIME JURIDICO       MAIS MEDICOS BOLSISTA  ...      SISRH  16/11/2021
# 49  REGIME JURIDICO      MAIS MEDICOS COOPERADO  ...      SISRH  16/11/2021
# 50  REGIME JURIDICO         K CARGO EM COMISSÃO  ...      SISRH  16/11/2021
# 51  REGIME JURIDICO            ADMITIDO LEI 500  ...      SISRH  16/11/2021
# 52  REGIME JURIDICO      CONTRATO DE EMERGENCIA  ...      SISRH  16/11/2021
#
# [11 rows x 5 columns]

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'AREA DE ATIVIDADE']
# Out:
#          QUALIFICADOR               VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 53  AREA DE ATIVIDADE  URGENCIA E EMERGENCIA        9820     SISRH  16/11/2021
# 54  AREA DE ATIVIDADE         ATENCAO BASICA       39243     SISRH  16/11/2021
# 55  AREA DE ATIVIDADE  ATENCAO ESPECIALIZADA       13960     SISRH  16/11/2021
# 56  AREA DE ATIVIDADE     ATENCAO HOSPITALAR       22067     SISRH  16/11/2021
# 57  AREA DE ATIVIDADE                 GESTAO        3204     SISRH  16/11/2021
# 58  AREA DE ATIVIDADE            EM TRANSITO        1640     SISRH  16/11/2021
# 59  AREA DE ATIVIDADE    VIGILANCIA EM SAUDE        3453     SISRH  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'SEXO BIOLOGICO']
# Out:
#       QUALIFICADOR VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 60  SEXO BIOLOGICO        M       23837     SISRH  16/11/2021
# 61  SEXO BIOLOGICO        F       69550     SISRH  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'NIVEL CATEGORIA']
# Out:
#        QUALIFICADOR VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 62  NIVEL CATEGORIA        M       40860     SISRH  16/11/2021
# 63  NIVEL CATEGORIA        O       18957     SISRH  16/11/2021
# 64  NIVEL CATEGORIA        S       33570     SISRH  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'ORGANIZACAO SOCIAL']
# Out:
#           QUALIFICADOR                 VARIAVEL  ...  SISORIGEM ATUALIZACAO
# 65  ORGANIZACAO SOCIAL                BOM PARTO  ...      SISRH  16/11/2021
# 66  ORGANIZACAO SOCIAL                    IABAS  ...      SISRH  16/11/2021
# 67  ORGANIZACAO SOCIAL            SIRIO LIBANES  ...      SISRH  16/11/2021
# 68  ORGANIZACAO SOCIAL                   PROSAM  ...      SISRH  16/11/2021
# 69  ORGANIZACAO SOCIAL                      SPX  ...      SISRH  16/11/2021
# 71  ORGANIZACAO SOCIAL          ALBERT EINSTEIN  ...      SISRH  16/11/2021
# 72  ORGANIZACAO SOCIAL             FUNDACAO ABC  ...      SISRH  16/11/2021
# 73  ORGANIZACAO SOCIAL                    CEJAM  ...      SISRH  16/11/2021
# 74  ORGANIZACAO SOCIAL                   SEPACO  ...      SISRH  16/11/2021
# 75  ORGANIZACAO SOCIAL                      FFM  ...      SISRH  16/11/2021
# 76  ORGANIZACAO SOCIAL           CASA DE ISABEL  ...      SISRH  16/11/2021
# 77  ORGANIZACAO SOCIAL                     INTS  ...      SISRH  16/11/2021
# 78  ORGANIZACAO SOCIAL  SANTA CASA DE SAO PAULO  ...      SISRH  16/11/2021
# 79  ORGANIZACAO SOCIAL                  QUIXOTE  ...      SISRH  16/11/2021
# 80  ORGANIZACAO SOCIAL                      ASF  ...      SISRH  16/11/2021
# 81  ORGANIZACAO SOCIAL                     APAE  ...      SISRH  16/11/2021
# 82  ORGANIZACAO SOCIAL           SANTA CATARINA  ...      SISRH  16/11/2021
# 83  ORGANIZACAO SOCIAL                     FIDI  ...      SISRH  16/11/2021
# 84  ORGANIZACAO SOCIAL          SANTA MARCELINA  ...      SISRH  16/11/2021
# 85  ORGANIZACAO SOCIAL      IRMAS HOSPITALEIRAS  ...      SISRH  16/11/2021
# 86  ORGANIZACAO SOCIAL               SALUS CREN  ...      SISRH  16/11/2021
# 87  ORGANIZACAO SOCIAL               MONTE AZUL  ...      SISRH  16/11/2021
# 88  ORGANIZACAO SOCIAL                  SECONCI  ...      SISRH  16/11/2021
# 89  ORGANIZACAO SOCIAL            PADRE MOREIRA  ...      SISRH  16/11/2021
# 90  ORGANIZACAO SOCIAL                     SPDM  ...      SISRH  16/11/2021
#
# [25 rows x 5 columns]

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'APOSENTADORIAS']
# Out:
#       QUALIFICADOR VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 70  APOSENTADORIAS     2021        1138      CRH3  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'ENTRADAS']
# Out:
#    QUALIFICADOR  VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 91     ENTRADAS  ENTRADAS          26     SISRH  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'SAIDAS']
# Out:
#    QUALIFICADOR VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 92       SAIDAS   SAIDAS          33     SISRH  16/11/2021

# %%
dados.loc[lambda dados: dados["QUALIFICADOR"] == 'ATENDIMENTOS EX-PROF']
# Out:
#             QUALIFICADOR VARIAVEL  FREQUENCIA SISORIGEM ATUALIZACAO
# 93  ATENDIMENTOS EX-PROF     2021       21492      SAPS  17/11/2021
